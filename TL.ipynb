# %%
from fastai import *
from fastai.tabular import *
import fastai

# %%
import os
path=os.chdir('/content/drive/MyDrive')

# %%
path=Path.cwd()

# %%
path
# Out:
# PosixPath('/content/drive/MyDrive')

# %%
path=path/'New folder (2)'
path.ls()
# Out:
# [PosixPath('/content/drive/MyDrive/New folder (2)/train.csv'),
#  PosixPath('/content/drive/MyDrive/New folder (2)/test.csv'),
#  PosixPath('/content/drive/MyDrive/New folder (2)/models')]

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/New folder (2)/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
test_df=pd.read_csv("/content/drive/MyDrive/New folder (2)/test.csv")
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
df.fillna(value=df.mean(),inplace=True)

# %%
test_df.fillna(value=df.mean(),inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
target='SalePrice'

# %%
procs=[FillMissing,Categorify,Normalize]

# %%
cont,cat = cont_cat_split(df, dep_var=target)

# %%
cont
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal']

# %%
cat
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  '3SsnPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
test=(TabularList.from_df(test_df,path=path,cat_names=cat,cont_names=cont,procs=procs))

# %%
test.cont_names
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal']

# %%
data=(TabularList.from_df(df,path=path,cat_names=cat,cont_names=cont,procs=procs)
     .split_by_rand_pct(0.2)
     .label_from_df(cols=target, label_cls=FloatList, log = True)
     .add_test(test)
     .databunch()
        )

# %%
data.cont_names
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal']

# %%
learn=tabular_learner(data,layers=[200,100], metrics=mean_absolute_error)

# %%
learn.summary()
# Out:
# TabularModel
# ...
# Layer (type)         Output Shape         Param #    Trainable
# ...
# Embedding            [8]                  128        True
# ______________________________________________________________________
# Embedding            [4]                  24         True
# ______________________________________________________________________
# Embedding            [3]                  9          True
# ______________________________________________________________________
# Embedding            [3]                  9          True
# ______________________________________________________________________
# Embedding            [4]                  20         True
# ______________________________________________________________________
# Embedding            [4]                  20         True
# ______________________________________________________________________
# Embedding            [3]                  9          True
# ...

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [4/6 00:02<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_absolute_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(30,1e-02)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_absolute_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008798</td>
#       <td>62677.582031</td>
#       <td>14.738206</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.008530</td>
#       <td>76295.140625</td>
#       <td>16.894491</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.008153</td>
#       <td>392520.437500</td>
#       <td>36.750004</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.009324</td>
#       <td>155722.109375</td>
#       <td>23.184109</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.009139</td>
#       <td>86383.750000</td>
#       <td>17.286053</td>
#       <td>00:00</td>
# ...

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrType</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
#       <th>Foundation</th>
#       <th>BsmtQual</th>
#       <th>BsmtCond</th>
#       <th>BsmtExposure</th>
#       <th>BsmtFinType1</th>
#       <th>BsmtFinType2</th>
#       <th>Heating</th>
#       <th>HeatingQC</th>
#       <th>CentralAir</th>
#       <th>Electrical</th>
# ...
